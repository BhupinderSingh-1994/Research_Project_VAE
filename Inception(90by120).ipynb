# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import time

# %%
import os
from sklearn.model_selection import train_test_split
from keras.preprocessing.image import load_img, img_to_array
import numpy as np
from tensorflow.keras.models import Model
import tensorflow as tf
from tensorflow.keras import layers, losses
import matplotlib.pyplot as plt

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

from tensorflow.keras import regularizers
from sklearn.metrics import confusion_matrix, classification_report

# %%
train_images = []
train_labels = []
test_images = []
test_labels = []

# %%
for category in range(4):
    images = [img_to_array(load_img(f'/content/drive/My Drive/Myocardial Infraction CNN/{category}/{file}', color_mode='grayscale', target_size=(90, 120))) for file in os.listdir(f'/content/drive/My Drive/Myocardial Infraction CNN/{category}')]

    labels = [category] * len(images)

    train_images_category, test_images_category, train_labels_category, test_labels_category = train_test_split(images, labels, test_size=0.2)

    train_images.extend(train_images_category)
    test_images.extend(test_images_category)
    train_labels.extend(train_labels_category)
    test_labels.extend(test_labels_category)

# %%
x_train = np.array(train_images)
x_test = np.array(test_images)
train_labels = np.array(train_labels)
test_labels = np.array(test_labels)

# %%
x_train = x_train.astype('float32')/255.
x_test = x_test.astype('float32')/255.

# %%
from tensorflow.keras.applications import InceptionV3

# %%
x_train = np.array([np.repeat(img, 3, axis=-1) for img in x_train])
x_test = np.array([np.repeat(img, 3, axis=-1) for img in x_test])

# %%
start_time = time.time()

# %%
base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=(x_train.shape[1], x_train.shape[2], x_train.shape[3]))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 0s 0us/step

# %%
for layer in base_model.layers:
    layer.trainable = False

# %%
x = base_model.output
x = layers.GlobalAveragePooling2D()(x)

x = layers.Dense(64, activation='relu')(x)


output = layers.Dense(4, activation='softmax')(x)

inception_model = Model(inputs=base_model.input, outputs=output)

# %%
inception_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
history2 = inception_model.fit(x_train, train_labels, epochs=100, validation_data=(x_test, test_labels))
# Out:
# Epoch 1/100
# 24/24 [==============================] - 16s 120ms/step - loss: 1.2557 - accuracy: 0.4683 - val_loss: 1.3312 - val_accuracy: 0.4171
# Epoch 2/100
# 24/24 [==============================] - 1s 24ms/step - loss: 1.0046 - accuracy: 0.5870 - val_loss: 0.9724 - val_accuracy: 0.6150
# Epoch 3/100
# 24/24 [==============================] - 1s 25ms/step - loss: 0.8062 - accuracy: 0.7139 - val_loss: 0.8729 - val_accuracy: 0.6898
# Epoch 4/100
# 24/24 [==============================] - 1s 26ms/step - loss: 0.6940 - accuracy: 0.7368 - val_loss: 0.8189 - val_accuracy: 0.6952
# Epoch 5/100
# 24/24 [==============================] - 1s 26ms/step - loss: 0.5956 - accuracy: 0.8057 - val_loss: 0.7783 - val_accuracy: 0.7112
# Epoch 6/100
# 24/24 [==============================] - 1s 28ms/step - loss: 0.5304 - accuracy: 0.8246 - val_loss: 0.7505 - val_accuracy: 0.7059
# Epoch 7/100
# 24/24 [==============================] - 1s 28ms/step - loss: 0.5207 - accuracy: 0.8138 - val_loss: 0.6446 - val_accuracy: 0.7807
# Epoch 8/100
# 24/24 [==============================] - 1s 28ms/step - loss: 0.4058 - accuracy: 0.8826 - val_loss: 0.6287 - val_accuracy: 0.7594
# Epoch 9/100
# 24/24 [==============================] - 1s 28ms/step - loss: 0.3714 - accuracy: 0.9015 - val_loss: 0.5980 - val_accuracy: 0.7594
# Epoch 10/100
# 24/24 [==============================] - 1s 28ms/step - loss: 0.3407 - accuracy: 0.9136 - val_loss: 0.5516 - val_accuracy: 0.7861
# Epoch 11/100
# 24/24 [==============================] - 1s 26ms/step - loss: 0.3068 - accuracy: 0.9177 - val_loss: 0.5164 - val_accuracy: 0.8128
# Epoch 12/100
# 24/24 [==============================] - 1s 22ms/step - loss: 0.2602 - accuracy: 0.9460 - val_loss: 0.5189 - val_accuracy: 0.8182
# Epoch 13/100
# 24/24 [==============================] - 1s 24ms/step - loss: 0.2255 - accuracy: 0.9609 - val_loss: 0.5138 - val_accuracy: 0.8182
# Epoch 14/100
# 24/24 [==============================] - 1s 22ms/step - loss: 0.1991 - accuracy: 0.9636 - val_loss: 0.4946 - val_accuracy: 0.8235
# Epoch 15/100
# 24/24 [==============================] - 1s 24ms/step - loss: 0.1846 - accuracy: 0.9690 - val_loss: 0.4698 - val_accuracy: 0.8342
# Epoch 16/100
# 24/24 [==============================] - 1s 22ms/step - loss: 0.1627 - accuracy: 0.9744 - val_loss: 0.5003 - val_accuracy: 0.8182
# Epoch 17/100
# 24/24 [==============================] - 1s 22ms/step - loss: 0.1729 - accuracy: 0.9568 - val_loss: 0.5215 - val_accuracy: 0.8128
# Epoch 18/100
# 24/24 [==============================] - 1s 24ms/step - loss: 0.1795 - accuracy: 0.9541 - val_loss: 0.4401 - val_accuracy: 0.8342
# Epoch 19/100
# 24/24 [==============================] - 1s 24ms/step - loss: 0.1171 - accuracy: 0.9865 - val_loss: 0.4480 - val_accuracy: 0.8503
# Epoch 20/100
# 24/24 [==============================] - 1s 23ms/step - loss: 0.1045 - accuracy: 0.9919 - val_loss: 0.4290 - val_accuracy: 0.8449
# Epoch 21/100
# 24/24 [==============================] - 1s 21ms/step - loss: 0.0984 - accuracy: 0.9919 - val_loss: 0.4115 - val_accuracy: 0.8717
# Epoch 22/100
# 24/24 [==============================] - 1s 24ms/step - loss: 0.0933 - accuracy: 0.9906 - val_loss: 0.4698 - val_accuracy: 0.8396
# Epoch 23/100
# 24/24 [==============================] - 1s 24ms/step - loss: 0.0808 - accuracy: 0.9946 - val_loss: 0.4304 - val_accuracy: 0.8449
# Epoch 24/100
# 24/24 [==============================] - 1s 22ms/step - loss: 0.0681 - accuracy: 0.9946 - val_loss: 0.4386 - val_accuracy: 0.8556
# Epoch 25/100
# 24/24 [==============================] - 1s 24ms/step - loss: 0.0667 - accuracy: 0.9919 - val_loss: 0.5138 - val_accuracy: 0.8342
# Epoch 26/100
# 24/24 [==============================] - 1s 24ms/step - loss: 0.0658 - accuracy: 0.9946 - val_loss: 0.4334 - val_accuracy: 0.8396
# Epoch 27/100
# 24/24 [==============================] - 1s 21ms/step - loss: 0.0566 - accuracy: 0.9960 - val_loss: 0.4252 - val_accuracy: 0.8717
# Epoch 28/100
# 24/24 [==============================] - 1s 22ms/step - loss: 0.0505 - accuracy: 0.9987 - val_loss: 0.4672 - val_accuracy: 0.8449
# Epoch 29/100
# 24/24 [==============================] - 1s 21ms/step - loss: 0.0479 - accuracy: 0.9960 - val_loss: 0.4230 - val_accuracy: 0.8770
# Epoch 30/100
# 24/24 [==============================] - 1s 27ms/step - loss: 0.0480 - accuracy: 0.9987 - val_loss: 0.4994 - val_accuracy: 0.8396
# Epoch 31/100
# 24/24 [==============================] - 1s 25ms/step - loss: 0.0368 - accuracy: 1.0000 - val_loss: 0.4744 - val_accuracy: 0.8556
# Epoch 32/100
# 24/24 [==============================] - 1s 28ms/step - loss: 0.0343 - accuracy: 1.0000 - val_loss: 0.4737 - val_accuracy: 0.8503
# Epoch 33/100
# 24/24 [==============================] - 1s 26ms/step - loss: 0.0315 - accuracy: 1.0000 - val_loss: 0.4567 - val_accuracy: 0.8556
# Epoch 34/100
# 24/24 [==============================] - 1s 28ms/step - loss: 0.0308 - accuracy: 1.0000 - val_loss: 0.4991 - val_accuracy: 0.8503
# Epoch 35/100
# 24/24 [==============================] - 1s 29ms/step - loss: 0.0298 - accuracy: 1.0000 - val_loss: 0.4914 - val_accuracy: 0.8449
# Epoch 36/100
# 24/24 [==============================] - 1s 28ms/step - loss: 0.0262 - accuracy: 1.0000 - val_loss: 0.4781 - val_accuracy: 0.8610
# Epoch 37/100
# 24/24 [==============================] - 1s 55ms/step - loss: 0.0246 - accuracy: 1.0000 - val_loss: 0.5053 - val_accuracy: 0.8449
# Epoch 38/100
# 24/24 [==============================] - 1s 27ms/step - loss: 0.0295 - accuracy: 0.9987 - val_loss: 0.4357 - val_accuracy: 0.8877
# Epoch 39/100
# 24/24 [==============================] - 1s 22ms/step - loss: 0.0266 - accuracy: 1.0000 - val_loss: 0
100
# 24/24 [==============================] - 1s 29ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.5930 - val_accuracy: 0.8449
# Epoch 88/100
# 24/24 [==============================] - 1s 25ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.6012 - val_accuracy: 0.8449
# Epoch 89/100
# 24/24 [==============================] - 1s 26ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.6237 - val_accuracy: 0.8449
# Epoch 90/100
# 24/24 [==============================] - 1s 28ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.6195 - val_accuracy: 0.8449
# Epoch 91/100
# 24/24 [==============================] - 1s 27ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.6103 - val_accuracy: 0.8449
# Epoch 92/100
# 24/24 [==============================] - 1s 26ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.6207 - val_accuracy: 0.8449
# Epoch 93/100
# 24/24 [==============================] - 1s 27ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.6398 - val_accuracy: 0.8449
# Epoch 94/100
# 24/24 [==============================] - 1s 25ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.6307 - val_accuracy: 0.8449
# Epoch 95/100
# 24/24 [==============================] - 1s 25ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.6391 - val_accuracy: 0.8449
# Epoch 96/100
# 24/24 [==============================] - 1s 22ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.6318 - val_accuracy: 0.8449
# Epoch 97/100
# 24/24 [==============================] - 1s 25ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.6254 - val_accuracy: 0.8449
# Epoch 98/100
# 24/24 [==============================] - 1s 24ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.6458 - val_accuracy: 0.8449
# Epoch 99/100
# 24/24 [==============================] - 1s 22ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.6487 - val_accuracy: 0.8449
# Epoch 100/100
# 24/24 [==============================] - 1s 22ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.6559 - val_accuracy: 0.8449

# %%
test_loss, test_acc = inception_model.evaluate(x_test, test_labels)


plt.figure(figsize=(12, 4))


plt.subplot(1, 2, 1)
plt.plot(history2.history['accuracy'], label='Training Accuracy')
plt.plot(history2.history['val_accuracy'], label='Test Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()


plt.subplot(1, 2, 2)
plt.plot(history2.history['loss'], label='Training Loss')
plt.plot(history2.history['val_loss'], label='Test Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
# Out:
# 6/6 [==============================] - 0s 17ms/step - loss: 0.6559 - accuracy: 0.8449

# %%
predictions = inception_model.predict(x_test)
binary_predictions = np.argmax(predictions, axis=1)
test_labels = test_labels.reshape(-1, 1)
conf_matrix = confusion_matrix(test_labels, binary_predictions)
# Out:
# 6/6 [==============================] - 1s 15ms/step

# %%
accuracy = np.trace(conf_matrix) / np.sum(conf_matrix)
precision = np.diagonal(conf_matrix) / np.sum(conf_matrix, axis=0)
recall = np.diagonal(conf_matrix) / np.sum(conf_matrix, axis=1)
f1_score = 2 * (precision * recall) / (precision + recall)


num_classes = len(conf_matrix)
specificity = []
for i in range(num_classes):
    true_negatives = np.sum(conf_matrix) - np.sum(conf_matrix[i, :]) - np.sum(conf_matrix[:, i]) + conf_matrix[i, i]
    false_positives = np.sum(conf_matrix[:, i]) - conf_matrix[i, i]
    specificity_class = true_negatives / (true_negatives + false_positives)
    specificity.append(specificity_class)

average_specificity = np.mean(specificity)

# Print the confusion matrix
print("Confusion Matrix:")
print(conf_matrix)

# Print the metrics
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1_score}")
print(f"Specificity for each class: {specificity}")
print(f"Average Specificity: {average_specificity}")
# Out:
# Confusion Matrix:
# [[48  0  0  0]
#  [ 3 28  6 10]
#  [ 2  4 25  4]
#  [ 0  0  0 57]]
# Accuracy: 0.8449
# Precision: [0.90566038 0.875      0.80645161 0.8028169 ]
# Recall: [1.         0.59574468 0.71428571 1.        ]
# F1 Score: [0.95049505 0.70886076 0.75757576 0.890625  ]
# Specificity for each class: [0.9640287769784173, 0.9714285714285714, 0.9605263157894737, 0.8923076923076924]
# Average Specificity: 0.9470728391260387

# %%
end_time = time.time()

elapsed_time = end_time - start_time
print(f"Training took {elapsed_time} seconds.")
# Out:
# Training took 96.3381609916687 seconds.
