# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import time

# %%
import os
from sklearn.model_selection import train_test_split
from keras.preprocessing.image import load_img, img_to_array
import numpy as np
from tensorflow.keras.models import Model
import tensorflow as tf
from tensorflow.keras import layers, losses
import matplotlib.pyplot as plt

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

from tensorflow.keras import regularizers
from sklearn.metrics import confusion_matrix, classification_report

# %%
train_images = []
train_labels = []
test_images = []
test_labels = []

# %%
for category in range(4):
    images = [img_to_array(load_img(f'/content/drive/My Drive/Myocardial Infraction CNN/{category}/{file}', color_mode='grayscale', target_size=(360, 480))) for file in os.listdir(f'/content/drive/My Drive/Myocardial Infraction CNN/{category}')]

    labels = [category] * len(images)

    train_images_category, test_images_category, train_labels_category, test_labels_category = train_test_split(images, labels, test_size=0.2)

    train_images.extend(train_images_category)
    test_images.extend(test_images_category)
    train_labels.extend(train_labels_category)
    test_labels.extend(test_labels_category)

# %%
x_train = np.array(train_images)
x_test = np.array(test_images)
train_labels = np.array(train_labels)
test_labels = np.array(test_labels)

# %%
x_train = x_train.astype('float32')/255.
x_test = x_test.astype('float32')/255.

# %%
print(x_train.shape[1])
# Out:
# 360

# %% [markdown]
# **InceptionV3**

# %%
start_time = time.time()

# %%
from tensorflow.keras.applications import InceptionV3

# %%
x_train = np.array([np.repeat(img, 3, axis=-1) for img in x_train])
x_test = np.array([np.repeat(img, 3, axis=-1) for img in x_test])

# %%
base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=(x_train.shape[1], x_train.shape[2], x_train.shape[3]))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 3s 0us/step

# %%
for layer in base_model.layers:
    layer.trainable = False

# %%
x = base_model.output
x = layers.GlobalAveragePooling2D()(x)

x = layers.Dense(64, activation='relu')(x)


output = layers.Dense(4, activation='softmax')(x)

inception_model = Model(inputs=base_model.input, outputs=output)

# %%
inception_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
history2 = inception_model.fit(x_train, train_labels, epochs=100, validation_data=(x_test, test_labels))
# Out:
# Epoch 1/100
# 24/24 [==============================] - 21s 323ms/step - loss: 1.1949 - accuracy: 0.4642 - val_loss: 1.1245 - val_accuracy: 0.4866
# Epoch 2/100
# 24/24 [==============================] - 3s 121ms/step - loss: 0.9435 - accuracy: 0.6451 - val_loss: 0.9423 - val_accuracy: 0.6471
# Epoch 3/100
# 24/24 [==============================] - 3s 123ms/step - loss: 0.8006 - accuracy: 0.6950 - val_loss: 0.8110 - val_accuracy: 0.7380
# Epoch 4/100
# 24/24 [==============================] - 3s 142ms/step - loss: 0.7084 - accuracy: 0.7314 - val_loss: 0.7776 - val_accuracy: 0.7326
# Epoch 5/100
# 24/24 [==============================] - 4s 168ms/step - loss: 0.6556 - accuracy: 0.7719 - val_loss: 0.7259 - val_accuracy: 0.7647
# Epoch 6/100
# 24/24 [==============================] - 3s 122ms/step - loss: 0.6311 - accuracy: 0.7530 - val_loss: 0.7013 - val_accuracy: 0.7647
# Epoch 7/100
# 24/24 [==============================] - 3s 123ms/step - loss: 0.5483 - accuracy: 0.8111 - val_loss: 0.6255 - val_accuracy: 0.7807
# Epoch 8/100
# 24/24 [==============================] - 4s 175ms/step - loss: 0.5001 - accuracy: 0.8354 - val_loss: 0.6212 - val_accuracy: 0.7968
# Epoch 9/100
# 24/24 [==============================] - 3s 142ms/step - loss: 0.5001 - accuracy: 0.8259 - val_loss: 0.6014 - val_accuracy: 0.7914
# Epoch 10/100
# 24/24 [==============================] - 3s 140ms/step - loss: 0.4670 - accuracy: 0.8543 - val_loss: 0.5256 - val_accuracy: 0.8289
# Epoch 11/100
# 24/24 [==============================] - 3s 120ms/step - loss: 0.4198 - accuracy: 0.8772 - val_loss: 0.5068 - val_accuracy: 0.8556
# Epoch 12/100
# 24/24 [==============================] - 3s 121ms/step - loss: 0.4048 - accuracy: 0.8866 - val_loss: 0.4707 - val_accuracy: 0.8663
# Epoch 13/100
# 24/24 [==============================] - 3s 121ms/step - loss: 0.3750 - accuracy: 0.9001 - val_loss: 0.4579 - val_accuracy: 0.8610
# Epoch 14/100
# 24/24 [==============================] - 3s 142ms/step - loss: 0.3759 - accuracy: 0.8812 - val_loss: 0.4441 - val_accuracy: 0.8877
# Epoch 15/100
# 24/24 [==============================] - 4s 170ms/step - loss: 0.3541 - accuracy: 0.8974 - val_loss: 0.4392 - val_accuracy: 0.8556
# Epoch 16/100
# 24/24 [==============================] - 3s 121ms/step - loss: 0.3375 - accuracy: 0.9042 - val_loss: 0.4557 - val_accuracy: 0.8770
# Epoch 17/100
# 24/24 [==============================] - 3s 124ms/step - loss: 0.3213 - accuracy: 0.9163 - val_loss: 0.4189 - val_accuracy: 0.9037
# Epoch 18/100
# 24/24 [==============================] - 3s 124ms/step - loss: 0.2924 - accuracy: 0.9312 - val_loss: 0.3847 - val_accuracy: 0.8770
# Epoch 19/100
# 24/24 [==============================] - 4s 163ms/step - loss: 0.2803 - accuracy: 0.9217 - val_loss: 0.3684 - val_accuracy: 0.8663
# Epoch 20/100
# 24/24 [==============================] - 3s 140ms/step - loss: 0.2921 - accuracy: 0.9258 - val_loss: 0.4138 - val_accuracy: 0.9037
# Epoch 21/100
# 24/24 [==============================] - 3s 121ms/step - loss: 0.2837 - accuracy: 0.9136 - val_loss: 0.3710 - val_accuracy: 0.8877
# Epoch 22/100
# 24/24 [==============================] - 3s 124ms/step - loss: 0.2593 - accuracy: 0.9366 - val_loss: 0.3547 - val_accuracy: 0.8770
# Epoch 23/100
# 24/24 [==============================] - 3s 123ms/step - loss: 0.2401 - accuracy: 0.9393 - val_loss: 0.3302 - val_accuracy: 0.9037
# Epoch 24/100
# 24/24 [==============================] - 3s 139ms/step - loss: 0.2306 - accuracy: 0.9393 - val_loss: 0.3277 - val_accuracy: 0.9144
# Epoch 25/100
# 24/24 [==============================] - 4s 168ms/step - loss: 0.2285 - accuracy: 0.9501 - val_loss: 0.3334 - val_accuracy: 0.9144
# Epoch 26/100
# 24/24 [==============================] - 3s 124ms/step - loss: 0.2259 - accuracy: 0.9433 - val_loss: 0.3087 - val_accuracy: 0.8930
# Epoch 27/100
# 24/24 [==============================] - 3s 120ms/step - loss: 0.2197 - accuracy: 0.9433 - val_loss: 0.3069 - val_accuracy: 0.9091
# Epoch 28/100
# 24/24 [==============================] - 3s 123ms/step - loss: 0.1966 - accuracy: 0.9487 - val_loss: 0.3002 - val_accuracy: 0.9144
# Epoch 29/100
# 24/24 [==============================] - 3s 135ms/step - loss: 0.1858 - accuracy: 0.9622 - val_loss: 0.2985 - val_accuracy: 0.9091
# Epoch 30/100
# 24/24 [==============================] - 3s 143ms/step - loss: 0.1904 - accuracy: 0.9514 - val_loss: 0.3160 - val_accuracy: 0.9091
# Epoch 31/100
# 24/24 [==============================] - 3s 131ms/step - loss: 0.1867 - accuracy: 0.9474 - val_loss: 0.2714 - val_accuracy: 0.9037
# Epoch 32/100
# 24/24 [==============================] - 3s 124ms/step - loss: 0.1783 - accuracy: 0.9541 - val_loss: 0.2728 - val_accuracy: 0.9305
# Epoch 33/100
# 24/24 [==============================] - 4s 161ms/step - loss: 0.1725 - accuracy: 0.9595 - val_loss: 0.2641 - val_accuracy: 0.9198
# Epoch 34/100
# 24/24 [==============================] - 4s 157ms/step - loss: 0.1682 - accuracy: 0.9595 - val_loss: 0.2512 - val_accuracy: 0.9412
# Epoch 35/100
# 24/24 [==============================] - 4s 170ms/step - loss: 0.1559 - accuracy: 0.9663 - val_loss: 0.2661 - val_accuracy: 0.9091
# Epoch 36/100
# 24/24 [==============================] - 3s 124ms/step - loss: 0.1518 - accuracy: 0.9636 - val_loss: 0.2463 - val_accuracy: 0.9465
# Epoch 37/100
# 24/24 [==============================] - 3s 123ms/step - loss: 0.1598 - accuracy: 0.9622 - val_loss: 0.2651 - val_accuracy: 0.9305
# Epoch 38/100
# 24/24 [==============================] - 3s 122ms/step - loss: 0.1521 - accuracy: 0.9595 - val_loss: 0.2395 - val_accuracy: 0.9465
# Epoch 39/100
# 24/24 [==============================] - 4s 148ms/step - loss: 0.1395 - accuracy: 0.9703 - val_loss: 0.2394 - val_accuracy: 0.9412
# Epoch 40/100
# 24/24 [==============================] - 4s 159ms/step - loss: 0.1362 - accuracy: 0.9622 - val_loss: 0.2614 - val_accuracy: 0.9144
# Epoch 41/100
# 24/24 [==============================] - 4s 178ms/step - loss: 0.1293 - accuracy: 0.9690 - val_loss: 0.2244 - val_accuracy: 0.9465
# Epoch 42/100
# 24/24 [==============================] - 3s 127ms/step - loss: 0.1267 - accuracy: 0.9703 - val_loss: 0.2507 - val_accuracy: 0.9412
# Epoch 43/100
# 24/24 [==============================] - 3s 122ms/step - loss: 0.1215 - accuracy: 0.9703 - val_loss: 0.2231 - val_accuracy: 0.9305
# Epoch 44/100
# 24/24 [==============================] - 3s 121ms/step - loss: 0.1332 - accuracy: 0.9676 - val_loss: 0.2124 - val_accuracy: 0.9519
# Epoch 45/100
# 24/24 [==============================] - 4s 155ms/step - loss: 0.1329 - accuracy: 0.9622 - val_loss: 0.2982 - val_accuracy: 0.8877
# Epoch 46/100
# 24/24 [==============================] - 4s 171ms/step - loss: 0.1332 - accuracy: 0.9636 - val_loss: 0.2193 - val_accuracy: 0.9465
# Epoch 47/100
# 24/24 [==============================] - 3s 124ms/step - loss: 0.1206 - accuracy: 0.9703 - val_loss: 0.2235 - val_accuracy: 0.9465
# Epoch 48/100
# 24/24 [==============================] - 3s 121ms/step - loss: 0.1415 - accuracy: 0.9636 - val_loss: 0.2914 - val_accuracy: 0.8984
# Epoch 49/100
# 24/24 [==============================] - 3s 121ms/step - loss: 0.1132 - accuracy: 0.9771 - val_loss: 0.2190 - val_accuracy: 0.9412
# Epoch 50/100
# 24/24 [==============================] - 4s 162ms/step - loss: 0.0966 - accuracy: 0.9798 - val_loss: 0.2087 - val_accuracy: 0.9519
# Epoch 51/100
# 24/24 [==============================] - 3s 143ms/step - loss: 0.0922 - accuracy: 0.9825 - val_loss: 0.2263 - val_accuracy: 0.9626
# Epoch 52/100
# 24/24 [==============================] - 3s 123ms/step - loss: 0.1010 - accuracy: 0.9771 - val_loss: 0.1971 - val_accuracy: 0.9465
# Epoch 53/100
# 24/24 [==============================] - 3s 122ms/step - loss: 0.0999 - accuracy: 0.9784 - val_loss: 0.1923 - val_accuracy: 0.9465
# Epoch 54/100
# 24/24 [==============================] - 3s 122ms/step - loss: 0.0852 - accuracy: 0.9838 - val_loss: 0.2008 - val_accuracy: 0.9572
# Epoch 55/100
# 24/24 [==============================] - 3s 131ms/step - loss: 0.0839 - accuracy: 0.9852 - val_loss: 0.1915 - val_accuracy: 0.9519
# Epoch 56/100
# 24/24 [==============================] - 4s 168ms/step - loss: 0.0827 - accuracy: 0.9838 - val_loss: 0.1842 - val_accuracy: 0.9572
# Epoch 57/100
# 24/24 [==============================] - 3s 126ms/step - loss: 0.0832 - accuracy: 0.9784 - val_loss: 0.1815 - val_accuracy: 0.9519
# Epoch 58/100
# 24/24 [==============================] - 3s 125ms/step - loss: 0.0783 - accuracy: 0.9852 - val_loss: 0.2169 - val_accuracy: 0.9679
# Epoch 59/100
# 24/24 [==============================] - 3s 124ms/step - loss: 0.0777 - accuracy: 0.9838 - val_loss: 0.1766 - val_accuracy: 0.9519
# Epoch 60/100
# 24/24 [==============================] - 3s 132ms/step - loss: 0.0759 - accuracy: 0.9879 - val_loss: 0.1867 - val_accuracy: 0.9626
# Epoch 61/100
# 24/24 [==============================] - 4s 169ms/step - loss: 0.0700 - accuracy: 0.9879 - val_loss: 0.1696 - val_accuracy: 0.9519
# Epoch 62/100
# 24/24 [==============================] - 3s 126ms/step - loss: 0.0656 - accuracy: 0.9879 - val_loss: 0.1740 - val_accuracy: 0.9679
# Epoch 63/100
# 24/24 [==============================] - 3s 124ms/step - loss: 0.0683 - accuracy: 0.9879 - val_loss: 0.1768 - val_accuracy: 0.9519
# Epoch 64/100
# 24/24 [==============================] - 3s 123ms/step - loss: 0.0629 - accuracy: 0.9906 - val_loss: 0.1703 - val_accuracy: 0.9572
# Epoch 65/100
# 24/24 [==============================] - 4s 155ms/step - loss: 0.0587 - accuracy: 0.9933 - val_loss: 0.1646 - val_accuracy: 0.9679
# Epoch 66/100
# 24/24 [==============================] - 4s 150ms/step - loss: 0.0710 - accuracy: 0.9865 - val_loss: 0.1750 - val_accuracy: 0.9519
# Epoch 67/100
# 24/24 [==============================] - 3s 130ms/step - loss: 0.0599 - accuracy: 0.9919 - val_loss: 0.1677 - val_accuracy: 0.9679
# Epoch 68/100
# 24/24 [==============================] - 3s 121ms/step - loss: 0.0588 - accuracy: 0.9919 - val_loss: 0.1854 - val_accuracy: 0.9679
# Epoch 69/100
# 24/24 [==============================] - 3s 127ms/step - loss: 0.0663 - accuracy: 0.9879 - val_loss: 0.1822 - val_accuracy: 0.9572
# Epoch 70/100
# 24/24 [==============================] - 4s 153ms/step - loss: 0.0573 - accuracy: 0.9906 - val_loss: 0.1683 - val_accuracy: 0.9626
# Epoch 71/100
# 24/24 [==============================] - 3s 144ms/step - loss: 0.0561 - accuracy: 0.9879 - val_loss: 0.2069 - val_accuracy: 0.9358
# Epoch 72/100
# 24/24 [==============================] - 3s 132ms/step - loss: 0.0701 - accuracy: 0.9879 - val_loss: 0.1694 - val_accuracy: 0.9572
# Epoch 73/100
# 24/24 [==============================] - 3s 123ms/step - loss: 0.0505 - accuracy: 0.9933 - val_loss: 0.1548 - val_accuracy: 0.9626
# Epoch 74/100
# 24/24 [==============================] - 3s 123ms/step - loss: 0.0444 - accuracy: 0.9946 - val_loss: 0.1586 - val_accuracy: 0.9626
# Epoch 75/100
# 24/24 [==============================] - 3s 125ms/step - loss: 0.0484 - accuracy: 0.9933 - val_loss: 0.1513 - val_accuracy: 0.9626
# Epoch 76/100
# 24/24 [==============================] - 4s 172ms/step - loss: 0.0433 - accuracy: 0.9973 - val_loss: 0.1629 - val_accuracy: 0.9626
# Epoch 77/100
# 24/24 [==============================] - 3s 132ms/step - loss: 0.0422 - accuracy: 0.9973 - val_loss: 0.1689 - val_accuracy: 0.9465
# Epoch 78/100
# 24/24 [==============================] - 3s 122ms/step - loss: 0.0395 - accuracy: 0.9960 - val_loss: 0.1503 - val_accuracy: 0.9626
# Epoch 79/100
# 24/24 [==============================] - 3s 124ms/step - loss: 0.0447 - accuracy: 0.9933 - val_loss: 0.1646 - val_accuracy: 0.9465
# Epoch 80/100
# 24/24 [==============================] - 3s 124ms/step - loss: 0.0402 - accuracy: 0.9960 - val_loss: 0.1464 - val_accuracy: 0.9679
# Epoch 81/100
# 24/24 [==============================] - 4s 172ms/step - loss: 0.0378 - accuracy: 0.9960 - val_loss: 0.1521 - val_accuracy: 0.9572
# Epoch 82/100
# 24/24 [==============================] - 3s 131ms/step - loss: 0.0375 - accuracy: 0.9960 - val_loss: 0.1435 - val_accuracy: 0.9733
# Epoch 83/100
# 24/24 [==============================] - 3s 124ms/step - loss: 0.0541 - accuracy: 0.9906 - val_loss: 0.1592 - val_accuracy: 0.9572
# Epoch 84/100
# 24/24 [==============================] - 3s 126ms/step - loss: 0.0354 - accuracy: 0.9987 - val_loss: 0.1440 - val_accuracy: 0.9572
# Epoch 85/100
# 24/24 [==============================] - 3s 124ms/step - loss: 0.0326 - accuracy: 0.9960 - val_loss: 0.1612 - val_accuracy: 0.9465
# Epoch 86/100
# 24/24 [==============================] - 4s 168ms/step - loss: 0.0352 - accuracy: 0.9973 - val_loss: 0.1536 - val_accuracy: 0.9626
# Epoch 87/100
# 24/24 [==============================] - 3s 131ms/step - loss: 0.0390 - accuracy: 0.9973 - val_loss: 0.1436 - val_accuracy: 0.9733
# Epoch 88/100
# 24/24 [==============================] - 3s 125ms/step - loss: 0.0308 - accuracy: 0.9973 - val_loss: 0.1522 - val_accuracy: 0.9626
# Epoch 89/100
# 24/24 [==============================] - 3s 124ms/step - loss: 0.0394 - accuracy: 0.9973 - val_loss: 0.1484 - val_accuracy: 0.9626
# Epoch 90/100
# 24/24 [==============================] - 3s 124ms/step - loss: 0.0273 - accuracy: 0.9973 - val_loss: 0.1480 - val_accuracy: 0.9626
# Epoch 91/100
# 24/24 [==============================] - 3s 144ms/step - loss: 0.0330 - accuracy: 0.9960 - val_loss: 0.1478 - val_accuracy: 0.9572
# Epoch 92/100
# 24/24 [==============================] - 4s 173ms/step - loss: 0.0326 - accuracy: 0.9960 - val_loss: 0.1440 - val_accuracy: 0.9626
# Epoch 93/100
# 24/24 [==============================] - 3s 123ms/step - loss: 0.0291 - accuracy: 0.9987 - val_loss: 0.1390 - val_accuracy: 0.9733
# Epoch 94/100
# 24/24 [==============================] - 3s 123ms/step - loss: 0.0273 - accuracy: 0.9973 - val_loss: 0.1474 - val_accuracy: 0.9626
# Epoch 95/100
# 24/24 [==============================] - 3s 125ms/step - loss: 0.0241 - accuracy: 0.9973 - val_loss: 0.1391 - val_accuracy: 0.9733
# Epoch 96/100
# 24/24 [==============================] - 4s 170ms/step - loss: 0.0239 - accuracy: 0.9987 - val_loss: 0.1370 - val_accuracy: 0.9786
# Epoch 97/100
# 24/24 [==============================] - 3s 136ms/step - loss: 0.0271 - accuracy: 0.9987 - val_loss: 0.1441 - val_accuracy: 0.9679
# Epoch 98/100
# 24/24 [==============================] - 3s 124ms/step - loss: 0.0248 - accuracy: 0.9987 - val_loss: 0.1393 - val_accuracy: 0.9733
# Epoch 99/100
# 24/24 [==============================] - 3s 122ms/step - loss: 0.0220 - accuracy: 0.9987 - val_loss: 0.1439 - val_accuracy: 0.9626
# Epoch 100/100
# 24/24 [==============================] - 3s 121ms/step - loss: 0.0202 - accuracy: 1.0000 - val_loss: 0.1483 - val_accuracy: 0.9733

# %%
test_loss, test_acc = inception_model.evaluate(x_test, test_labels)


plt.figure(figsize=(12, 4))


plt.subplot(1, 2, 1)
plt.plot(history2.history['accuracy'], label='Training Accuracy')
plt.plot(history2.history['val_accuracy'], label='Test Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()


plt.subplot(1, 2, 2)
plt.plot(history2.history['loss'], label='Training Loss')
plt.plot(history2.history['val_loss'], label='Test Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
# Out:
# 6/6 [==============================] - 1s 102ms/step - loss: 0.1483 - accuracy: 0.9733

# %%
predictions = inception_model.predict(x_test)
binary_predictions = np.argmax(predictions, axis=1)
test_labels = test_labels.reshape(-1, 1)
conf_matrix = confusion_matrix(test_labels, binary_predictions)
# Out:
# 6/6 [==============================] - 2s 85ms/step

# %%
accuracy = np.trace(conf_matrix) / np.sum(conf_matrix)
precision = np.diagonal(conf_matrix) / np.sum(conf_matrix, axis=0)
recall = np.diagonal(conf_matrix) / np.sum(conf_matrix, axis=1)
f1_score = 2 * (precision * recall) / (precision + recall)


num_classes = len(conf_matrix)
specificity = []
for i in range(num_classes):
    true_negatives = np.sum(conf_matrix) - np.sum(conf_matrix[i, :]) - np.sum(conf_matrix[:, i]) + conf_matrix[i, i]
    false_positives = np.sum(conf_matrix[:, i]) - conf_matrix[i, i]
    specificity_class = true_negatives / (true_negatives + false_positives)
    specificity.append(specificity_class)

average_specificity = np.mean(specificity)

# Print the confusion matrix
print("Confusion Matrix:")
print(conf_matrix)

# Print the metrics
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1_score}")
print(f"Specificity for each class: {specificity}")
print(f"Average Specificity: {average_specificity}")
# Out:
# Confusion Matrix:
# [[48  0  0  0]
#  [ 0 45  1  1]
#  [ 0  3 32  0]
#  [ 0  0  0 57]]
# Accuracy: 0.9733
# Precision: [1.         0.9375     0.96969697 0.98275862]
# Recall: [1.         0.95744681 0.91428571 1.        ]
# F1 Score: [1.         0.94736842 0.94117647 0.99130435]
# Specificity for each class: [1.0, 0.9785714285714285, 0.993421052631579, 0.9923076923076923]
# Average Specificity: 0.9910750433776749

# %%
end_time = time.time()

elapsed_time = end_time - start_time
print(f"Training took {elapsed_time} seconds.")
# Out:
# Training took 408.1336762905121 seconds.
